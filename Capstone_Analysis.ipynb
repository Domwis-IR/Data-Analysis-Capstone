# %%
import io
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 파일 열기

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/Final_M+S_2.csv'
data = pd.read_csv(filename)
data
# Out:
#            date  city  emd    code  ...  market  readPop  workPop  visitPop
# 0      20170100   제주시  한림읍  I55112  ...  1610.0    20434     1522     11107
# 1      20170100   제주시  한림읍  G47813  ...  1091.0    20434     1522     11107
# 2      20170100   제주시  한림읍  I56112  ...   234.0    20434     1522     11107
# 3      20170100   제주시  한림읍  I56111  ...  6259.0    20434     1522     11107
# 4      20170100   제주시  한림읍  G47214  ...   888.0    20434     1522     11107
# ...         ...   ...  ...     ...  ...     ...      ...      ...       ...
# 38578  20191200  서귀포시  예래동  G47842  ...   128.0     3639      916      8302
# 38579  20191200  서귀포시  예래동  R91121  ...    16.0     3639      916      8302
# 38580  20191200  서귀포시  예래동  G47130  ...     3.0     3639      916      8302
# 38581  20191200  서귀포시  예래동  L69210  ...   218.0     3639      916      8302
# 38582  20191200  서귀포시  예래동  S96121  ...    19.0     3639      916      8302
#
# [38583 rows x 9 columns]

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/Final_2020.csv'
data2 = pd.read_csv(filename)
data2 = data2.dropna()
data2
# Out:
#             date city  emd    code        money  readPop  workPop  visitPop
# 0     20200100.0  제주시  한림읍  G47216     901000.0  18363.0   1402.0    8982.0
# 1     20200100.0  제주시  한림읍  R91121   89860925.0  18363.0   1402.0    8982.0
# 2     20200100.0  제주시  한림읍  G47214   20859100.0  18363.0   1402.0    8982.0
# 3     20200100.0  제주시  한림읍  G47842   21847600.0  18363.0   1402.0    8982.0
# 4     20200100.0  제주시  한림읍  G47190  462143110.0  18363.0   1402.0    8982.0
# ...          ...  ...  ...     ...          ...      ...      ...       ...
# 2762  20200400.0  제주시  도두동  G47712   28589608.0   1179.0    176.0    2311.0
# 2763  20200400.0  제주시  도두동  G47711   59404309.0   1179.0    176.0    2311.0
# 2764  20200400.0  제주시  도두동  G47122   54187470.0   1179.0    176.0    2311.0
# 2765  20200400.0  제주시  도두동  I56111  175033940.0   1179.0    176.0    2311.0
# 2766  20200400.0  제주시  예래동  I55113   35067000.0   3023.0    547.0    3669.0
#
# [2767 rows x 8 columns]

# %%
filename2 = '/content/drive/MyDrive/Colab Notebooks/업종코드.csv'
code_name = pd.read_csv(filename2)
Code = []
Code_n = []
c_list ={}
for i in range(len(code_name)):
  for j in code_name['업종코드']:
    Code.append(j)
  for j in code_name['업종명']:
    Code_n.append(j)
for i in range(len(code_name)):
  c_list[Code[i]] = Code_n[i]

print(c_list)
# Out:
# {'G47121': '슈퍼마켓', 'I55112': '여관업', 'I56111': '한식 음식점업', 'G47842': '관광 민예품 및 선물용품 소매업', 'G47813': '화장품 및 방향제 소매업', 'I55111': '호텔업', 'I56112': '중식 음식점업', 'I56113': '일식 음식점업', 'G47215': '빵 및 과자류 소매업', 'G47214': '과실 및 채소 소매업', 'G47213': '수산물 소매업', 'G47712': '차량용 가스 충전업', 'G47711': '차량용 주유소 운영업', 'L69210': '스포츠 및 레크레이션 용품 임대업', 'G47190': '그외 기타 종합 소매업', 'G47119': '기타 대형 종합 소매업', 'I56220': '비알콜 음료점업', 'S96121': '욕탕업', 'R91299': '그외 기타 분류안된 오락관련 서비스업', 'R91139': '그외 기타 스포츠시설 운영업', 'H51100': '정기 항공 운송업', 'I55113': '휴양콘도 운영업', 'R91249': '기타 갬블링 및 베팅업', 'H49212': '버스 운송업', 'R91121': '골프장 운영업', 'H50121': '내항 여객 운송업', 'S96122': '마사지업', 'L69110': '자동차 임대업', 'G47216': '건강보조식품 소매업', 'N75992': '전시 및 행사 대행업', 'N75211': '여행사업', 'I56114': '서양식 음식점업', 'I56119': '기타 외국식 음식점업', 'I56211': '일반유흥 주점업', 'I56192': '피자, 햄버거, 샌드위치 및 유사 음식점업', 'I56219': '기타 주점업', 'G47122': '체인화 편의점', 'G47212': '육류 소매업', 'G47129': '기타음식료품위주종합소매업', 'G47130': '면세점', 'R91239': '기타 수상오락 서비스업', 'H49231': '택시 운송업'}

# %%
filename2 = '/content/drive/MyDrive/Colab Notebooks/업종코드.csv'
code_name = pd.read_csv(filename2)
Code = []
Code_n = []
c_list2 ={}
for i in range(len(code_name)):
  for j in code_name['업종명']:
    Code.append(j)
  for j in code_name['업종코드']:
    Code_n.append(j)
for i in range(len(code_name)):
  c_list2[Code[i]] = Code_n[i]

print(c_list2)
# Out:
# {'슈퍼마켓': 'G47121', '여관업': 'I55112', '한식 음식점업': 'I56111', '관광 민예품 및 선물용품 소매업': 'G47842', '화장품 및 방향제 소매업': 'G47813', '호텔업': 'I55111', '중식 음식점업': 'I56112', '일식 음식점업': 'I56113', '빵 및 과자류 소매업': 'G47215', '과실 및 채소 소매업': 'G47214', '수산물 소매업': 'G47213', '차량용 가스 충전업': 'G47712', '차량용 주유소 운영업': 'G47711', '스포츠 및 레크레이션 용품 임대업': 'L69210', '그외 기타 종합 소매업': 'G47190', '기타 대형 종합 소매업': 'G47119', '비알콜 음료점업': 'I56220', '욕탕업': 'S96121', '그외 기타 분류안된 오락관련 서비스업': 'R91299', '그외 기타 스포츠시설 운영업': 'R91139', '정기 항공 운송업': 'H51100', '휴양콘도 운영업': 'I55113', '기타 갬블링 및 베팅업': 'R91249', '버스 운송업': 'H49212', '골프장 운영업': 'R91121', '내항 여객 운송업': 'H50121', '마사지업': 'S96122', '자동차 임대업': 'L69110', '건강보조식품 소매업': 'G47216', '전시 및 행사 대행업': 'N75992', '여행사업': 'N75211', '서양식 음식점업': 'I56114', '기타 외국식 음식점업': 'I56119', '일반유흥 주점업': 'I56211', '피자, 햄버거, 샌드위치 및 유사 음식점업': 'I56192', '기타 주점업': 'I56219', '체인화 편의점': 'G47122', '육류 소매업': 'G47212', '기타음식료품위주종합소매업': 'G47129', '면세점': 'G47130', '기타 수상오락 서비스업': 'R91239', '택시 운송업': 'H49231'}

# %% [markdown]
# # 업종별 매출액과 유동인구 사이의 상관분석

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
font_location = '/content/drive/MyDrive/Colab Notebooks/NanumSquareRoundR.ttf'
fontprop = fm.FontProperties(fname=font_location, size = 15)

emd1 = ["한림읍", "애월읍", "구좌읍", "조천읍", "한경면","추자면",
        "우도면", "일도일동","일도이동","이도일동","이도이동",
        "삼도일동","삼도이동","용담일동","용담이동","건입동","화북동","삼양동",
        "봉개동","아라동","오라동","연동","노형동","외도동","이호동","도두동"]
emd2 = ["대정읍","남원읍","성산읍","안덕면","표선면","송산동","서귀동","효돈동",
        "영천동","동홍동","서홍동","대륜동","대천동","중문동","예래동"]

#e = data[data['emd'].isin(["외도동"])]


code_l = []
for i in data['code']:
  if i not in code_l:
    code_l.append(i)
code_l.sort()
n = len(code_l)
print(n)
print(code_l)
plt.figure(figsize=(28,24)) # 먼저 창을 만들고
n=1

for code_ in code_l:
  c = data[data['code'].isin([code_])]
  df = pd.DataFrame(data=c[['money','readPop','workPop','visitPop']])
  ax = plt.subplot(7,6,n)
  name = c_list[code_]
  length = len(c)
  plt.title(code_+' '+name+'('+str(length)+')',fontsize=15,fontproperties= fontprop)
  corr = df.corr(method='pearson')
  #df_heatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 10}, fmt = '.2f', square = True, cmap = 'Blues')
  #fig, ax2 = plt.subplots( figsize=(7,7) )
  # 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
  mask = np.zeros_like(corr, dtype=np.bool)
  mask[np.triu_indices_from(mask)] = True
  # 히트맵을 그린다
  sns.heatmap(corr, 
              cmap = 'Blues', 
              annot = True,   # 실제 값을 표시한다
              annot_kws={'size' : 15},
              mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
              linewidths=.5,  # 경계면 실선으로 구분하기
              cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
              vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
            )  
  n+=1
  print(code_)

plt.tight_layout()  # 창 크기에 맞게 조정
plt.show()
# Out:
# 40
# ['G47119', 'G47121', 'G47122', 'G47129', 'G47130', 'G47190', 'G47212', 'G47213', 'G47214', 'G47215', 'G47216', 'G47711', 'G47712', 'G47813', 'G47842', 'H50121', 'H51100', 'I55111', 'I55112', 'I55113', 'I56111', 'I56112', 'I56113', 'I56114', 'I56119', 'I56192', 'I56211', 'I56219', 'I56220', 'L69110', 'L69210', 'N75211', 'N75992', 'R91121', 'R91139', 'R91239', 'R91249', 'R91299', 'S96121', 'S96122']
# G47119
# G47121
# G47122
# G47129
# G47130
# G47190
# G47212
# G47213
# G47214
# G47215
# G47216
# G47711
# G47712
# G47813
# G47842
# H50121
# H51100
# I55111
# I55112
# I55113
# I56111
# I56112
# I56113
# I56114
# I56119
# I56192
# I56211
# I56219
# I56220
# L69110
# L69210
# N75211
# N75992
# R91121
# R91139
# R91239
# R91249
# R91299
# S96121
# S96122

# %% [markdown]
# # 분석시작!
# 1. 업종코드 입력: index로
# 2. 해당 업종에 대해 dendrogram 및 상관계수 분석 결과 출력<br>
# 해당 결과에 따라 군집 갯수 결정 및 군집 기준(가장 상관계수가 높은 값) 결정
# 3. 군집갯수에 따라 Clustering 진행
# 4. 그룹별 해당하는 읍면동에 대해 상관계수 출력
# 5. 그룹별 매출액과 유동인구 사이의 상관분석 출력
# 6. 업종 전체에 대해 매출액 추정
# 7. 그룹별 매출액 추정 결과 값 출력

# %%
#Parameter Setting
code_n = 3

# %%
import scipy.cluster.hierarchy as shc
x_ = ['readPop','workPop','visitPop']

c = data[data['code'].isin([code_l[code_n]])]
print(len(c))
print(code_l[code_n], c_list[code_l[code_n]])
data_k = c.iloc[:,[6,7,8]]
plt.figure(figsize=(14, 7))
plt.title("Money Dendograms")
dend = shc.dendrogram(shc.linkage(data_k, method='ward'))

plt.figure(figsize=(6,6))
length = len(c)
plt.title(c_list[code_l[code_n]]+' '+'('+str(length)+')',fontsize=15,fontproperties= fontprop)
df = pd.DataFrame(data=c[['money','readPop','workPop','visitPop']])
corr = df.corr(method='pearson')
#df_heatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 10}, fmt = '.2f', square = True, cmap = 'Blues')
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
# 히트맵을 그린다
sns.heatmap(corr, 
            cmap = 'Blues', 
            annot = True,   # 실제 값을 표시한다
            annot_kws={'size' : 15},
            mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
            linewidths=.5,  # 경계면 실선으로 구분하기
            cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
            vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
          ) 
plt.show()
# Out:
# 1273
# G47129 기타음식료품위주종합소매업

# %%
choose = 2  #분류기준: readPop(0), workPop(1), visitPop(2)
num_K = 4   #군집갯수

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_location = '/content/drive/MyDrive/Colab Notebooks/NanumSquareRoundR.ttf'
fontprop = fm.FontProperties(fname=font_location, size = 15)

from sklearn.cluster import KMeans
from sklearn.cluster import DBSCAN
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import MinMaxScaler

emd1 = ["한림읍", "애월읍", "구좌읍", "조천읍", "한경면","추자면",
        "우도면", "일도일동","일도이동","이도일동","이도이동",
        "삼도일동","삼도이동","용담일동","용담이동","건입동","화북동","삼양동",
        "봉개동","아라동","오라동","연동","노형동","외도동","이호동","도두동"]
emd2 = ["대정읍","남원읍","성산읍","안덕면","표선면","송산동","서귀동","효돈동",
        "영천동","동홍동","서홍동","대륜동","대천동","중문동","예래동"]



x_ = ['readPop','workPop','visitPop']

plt.figure(figsize=(18,12)) # 먼저 창을 만들고
n=1

for i in range(3):
  plt.subplot(230+n)
  X = c[x_[i]]
  y = c['money']
  df = pd.DataFrame({x_[i]:X,'money':y})
  scaler = MinMaxScaler()
  scaler.fit(df)
  output = scaler.transform(df)
  output = pd.DataFrame(output, columns=df.columns, index=list(df.index.values))
  plt.title("Before: "+x_[i], fontsize=15)
  #plt.plot(X,y, "o")
  plt.plot(output.iloc[:,[0]],output.iloc[:,[1]],"o")
  #plt.axis([X.min(), X.max(), y.min(), y.max()])
  #plt.grid()
  #plt.show()
  #cluster = DBSCAN(eps=0.001, min_samples=5).fit(df.values)
  plt.subplot(233+n) 
  #cluster = KMeans(n_clusters=num_K, n_init=num_K*3, random_state=True).fit(output.values)
  cluster = AgglomerativeClustering(n_clusters = num_K).fit(output.values)
  output['cluster_km'] = cluster.labels_
  k_label = output['cluster_km'].values
  if i == choose:
    result = c.assign(cluster_km=k_label)
  plt.title("After - KMeans: "+x_[i], fontsize=15)
  plt.scatter(output.iloc[:,[0]],output.iloc[:,[1]],c=output['cluster_km'])
  n += 1

plt.tight_layout()  # 창 크기에 맞게 조정
plt.show()
result
# Out:
#            date  city  emd    code  ...  readPop  workPop  visitPop  cluster_km
# 27     20170100   제주시  한림읍  G47129  ...    20434     1522     11107           0
# 57     20170100   제주시  애월읍  G47129  ...    35750     3458     24806           2
# 86     20170100   제주시  구좌읍  G47129  ...    13655     1212      9815           0
# 117    20170100   제주시  조천읍  G47129  ...    20311     2196     15505           0
# 141    20170100   제주시  한경면  G47129  ...     6166      493      3588           3
# ...         ...   ...  ...     ...  ...      ...      ...       ...         ...
# 38440  20191200  서귀포시  동홍동  G47129  ...    22385     2227      9302           0
# 38468  20191200  서귀포시  서홍동  G47129  ...     6678      605      4697           3
# 38493  20191200  서귀포시  대륜동  G47129  ...    16310     1820     10185           0
# 38546  20191200  서귀포시  중문동  G47129  ...    11958      933      6775           0
# 38572  20191200  서귀포시  예래동  G47129  ...     3639      916      8302           0
#
# ...

# %% [markdown]
# 그룹별 읍면동 출력 및 결과 하나의 list로 합치기

# %%
if num_K >= 3:
  group1 = result[result['cluster_km'] == 0]
  print(pd.unique(group1['emd']))
  print(len(pd.unique(group1['emd'])))
  group2 = result[result['cluster_km'] == 1]
  print(pd.unique(group2['emd']))
  print(len(pd.unique(group2['emd'])))
  group3 = result[result['cluster_km'] == 2]
  print(pd.unique(group3['emd']))
  print(len(pd.unique(group3['emd'])))
if num_K == 4:
  group4 = result[result['cluster_km'] == 3]
  print(pd.unique(group4['emd']))
  print(len(pd.unique(group4['emd'])))
# Out:
# ['한림읍' '구좌읍' '조천읍' '일도이동' '이도일동' '삼도일동' '삼도이동' '건입동' '화북동' '삼양동' '아라동'
#  '오라동' '대정읍' '남원읍' '성산읍' '안덕면' '표선면' '동홍동' '대륜동' '대천동' '중문동' '예래동' '용담일동'
#  '외도동']
# 24
# ['이도이동' '연동' '노형동' '아라동']
# 4
# ['애월읍']
# 1
# ['한경면' '우도면' '일도일동' '용담일동' '외도동' '이호동' '송산동' '서귀동' '효돈동' '영천동' '서홍동' '삼양동']
# 12

# %%
if num_K >= 3:
  group1_emd = pd.unique(group1['emd']).tolist()
  group2_emd = pd.unique(group2['emd']).tolist()
  group3_emd = pd.unique(group3['emd']).tolist()
if num_K == 3:
  group_emd = [group1_emd, group2_emd, group3_emd]
  group = [group1, group2, group3]
if num_K == 4:
  group4_emd = pd.unique(group4['emd']).tolist()
  group_emd = [group1_emd, group2_emd, group3_emd, group4_emd]
  group = [group1, group2, group3, group4]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
font_location = '/content/drive/MyDrive/Colab Notebooks/NanumSquareRoundR.ttf'
fontprop = fm.FontProperties(fname=font_location, size = 15)

for i in range(num_K):
  e = group[i]
  plt.figure(figsize=(28,24)) # 먼저 창을 만들고
  n=1
  for emd_ in group_emd[i]:
    c = e[e['emd'].isin([emd_])]
    df = pd.DataFrame(data=c[['money','readPop','workPop','visitPop']])
    ax = plt.subplot(7,6,n)
    length = len(c)
    plt.title(emd_+'('+str(length)+')',fontsize=15,fontproperties= fontprop)
    corr = df.corr(method='pearson')
    #df_heatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 10}, fmt = '.2f', square = True, cmap = 'Blues')
    #fig, ax2 = plt.subplots( figsize=(7,7) )
    # 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
    mask = np.zeros_like(corr, dtype=np.bool)
    mask[np.triu_indices_from(mask)] = True
    # 히트맵을 그린다
    sns.heatmap(corr, 
                cmap = 'Blues', 
                annot = True,   # 실제 값을 표시한다
                annot_kws={'size' : 15},
                mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
                linewidths=.5,  # 경계면 실선으로 구분하기
                cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
                vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
              )  
    n+=1
    print(emd_)

  plt.tight_layout()  # 창 크기에 맞게 조정
  plt.show()
# Out:
# 봉개동
# 도두동
# 중문동
# 일도일동
# 대륜동
# 봉개동
# 표선면
# 구좌읍
# 이도일동
# 남원읍
# 대정읍
# 삼도이동
# 봉개동
# 표선면
# 서귀동
# 삼도일동
# 대천동
# 도두동
# 서귀동
# 일도일동

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.font_manager as fm
import numpy as np
font_location = '/content/drive/MyDrive/Colab Notebooks/NanumSquareRoundR.ttf'
fontprop = fm.FontProperties(fname=font_location, size = 15)


plt.figure(figsize=(28,24)) # 먼저 창을 만들고
n=1
for i in range(num_K):
  c = group[i]
  df = pd.DataFrame(data=c[['money','market','readPop','workPop','visitPop']])
  ax = plt.subplot(7,6,n)
  #name = c_list[0]
  length = len(c)
  plt.title("Group"+str(i+1)+ ' '+'('+str(length)+')',fontsize=15,fontproperties= fontprop) 
  corr = df.corr(method='pearson')
  #df_heatmap = sns.heatmap(corr, cbar = True, annot = True, annot_kws={'size' : 10}, fmt = '.2f', square = True, cmap = 'Blues')
  #fig, ax2 = plt.subplots( figsize=(7,7) )
  # 삼각형 마스크를 만든다(위 쪽 삼각형에 True, 아래 삼각형에 False)
  mask = np.zeros_like(corr, dtype=np.bool)
  mask[np.triu_indices_from(mask)] = True
  # 히트맵을 그린다
  sns.heatmap(corr, 
              cmap = 'Blues', 
              annot = True,   # 실제 값을 표시한다
              annot_kws={'size' : 15},
              mask=mask,      # 표시하지 않을 마스크 부분을 지정한다
              linewidths=.5,  # 경계면 실선으로 구분하기
              cbar_kws={"shrink": .5},# 컬러바 크기 절반으로 줄이기
              vmin = -1,vmax = 1   # 컬러바 범위 -1 ~ 1
            )  
  n+=1

plt.tight_layout()  # 창 크기에 맞게 조정
plt.show()

# %%
#그룹별 다중회귀분석을 이용한 매출 추정
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import minmax_scale

plt.figure(figsize=(6,6)) # 먼저 창을 만들고


train = data[data['code'].isin([code[code_n]])]
test = data2[data2['code'].isin([code[code_n]])]

X = train.iloc[:,[6,7,8]]
X = minmax_scale(X, axis=0, copy=True)
y = train.iloc[:,[4]]
y = minmax_scale(y, axis=0, copy=True)
X_test = test.iloc[:,[5,6,7]]
X_test = minmax_scale(X_test, axis=0, copy=True)
y_test = test.iloc[:,[4]]
y_test = minmax_scale(y_test, axis=0, copy=True)
mlr = LinearRegression()
mlr.fit(X, y)
y_predict = mlr.predict(X_test)
plt.scatter(y_test, y_predict, alpha=0.7)
plt.title('Total'+ ' ('+str(len(y_test))+') ' + str(round(mlr.score(X, y),2)))

plt.show()

# %%
#그룹별 다중회귀분석을 이용한 매출 추정
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import minmax_scale

plt.figure(figsize=(24,6)) # 먼저 창을 만들고

n=1
 
for i in range(num_K):
  #if i == 2:
  #  continue
  plt.subplot(140+n)
  test = data2[data2['emd'].isin(group_emd[i])]
  test = test[test['code'].isin([code[code_n]])]

  X = group[i].iloc[:,[6,7,8]]
  X = minmax_scale(X, axis=0, copy=True)
  y = group[i].iloc[:,[4]]
  y = minmax_scale(y, axis=0, copy=True)
  X_test = test.iloc[:,[5,6,7]]
  X_test = minmax_scale(X_test, axis=0, copy=True)
  y_test = test.iloc[:,[4]]
  y_test = minmax_scale(y_test, axis=0, copy=True)
  mlr = LinearRegression()
  mlr.fit(X, y)
  y_predict = mlr.predict(X_test)
  plt.scatter(y_test, y_predict, alpha=0.7)
  plt.title('Group'+str(i+1)+ ' ('+str(len(y_test))+') ' + str(round(mlr.score(X, y),2)))
  n += 1

plt.show()

# %% [markdown]
# # 실패했던 1차 분석결과
# 나이대별(20대 이하, 30대~50대, 60대 이상) 데이터를 이용해서 선형회귀분석

# %%
filename = '/content/drive/MyDrive/Colab Notebooks/Final_M+S.csv'
data = pd.read_csv(filename)
print(data)
filename2 = '/content/drive/MyDrive/Colab Notebooks/업종코드.csv'
code_name = pd.read_csv(filename2)
print(code_name)
# Out:
#             date  city  emd    code  ...  market  readPop  workPop  visitPop
# 0       20170100   제주시  한림읍  I55112  ...  1610.0    16097      950     11516
# 1       20170100   제주시  한림읍  G47813  ...  1091.0    16097      950     11516
# 2       20170100   제주시  한림읍  I56112  ...   234.0    16097      950     11516
# 3       20170100   제주시  한림읍  I56111  ...  6259.0    16097      950     11516
# 4       20170100   제주시  한림읍  G47215  ...   392.0    16097      950     11516
# ...          ...   ...  ...     ...  ...     ...      ...      ...       ...
# 108044  20191200  서귀포시  예래동  G47842  ...   128.0     3064      268      3590
# 108045  20191200  서귀포시  예래동  R91121  ...    16.0     3064      268      3590
# 108046  20191200  서귀포시  예래동  G47130  ...     3.0     3064      268      3590
# 108047  20191200  서귀포시  예래동  L69210  ...   218.0     3064      268      3590
# 108048  20191200  서귀포시  예래동  S96121  ...    19.0     3064      268      3590
#
# [108049 rows x 10 columns]
# ...

# %%
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font_location = '/content/drive/MyDrive/Colab Notebooks/NanumSquareRoundR.ttf'
fontprop = fm.FontProperties(fname=font_location, size = 15)

data = data[data['emd'].isin(["외도동"])]

code_l = []
for i in data['code']:
  if i not in code_l:
    code_l.append(i)
code_l.sort()

print(len(code_l))


x_ = ['readPop','workPop','visitPop']
for j in range(len(code_l)):
  plt.figure(figsize=(18,6)) # 먼저 창을 만들고
  n=1
  c = data[data['code'].isin([code_l[j]])]
  for i in range(3):
    ax = plt.subplot(1,3,n)
    k = code_l[j]
    name = c_list[k]
    length = len(c)
    plt.title(k+' '+name+'('+str(length)+')',fontsize=15,fontproperties= fontprop)
    #corr = df.corr(method='pearson')
    X = c[x_[n-1]]
    y = c['money']
    line_fitter = LinearRegression()
    line_fitter.fit(X.values.reshape(-1,1), y)
    plt.plot(X, y, 'o')
    plt.xlabel(x_[n-1])
    plt.ylabel('money')
    plt.plot(X,line_fitter.predict(X.values.reshape(-1,1)))
    print(line_fitter.coef_)
    print(line_fitter.intercept_)
    n+=1
  plt.tight_layout()  # 창 크기에 맞게 조정
  plt.show()
# Out:
# 30
# [15205.98809884]
# -51991577.081212476
# [286658.64041787]
# -73070398.12327112
# [41915.4737318]
# -123322495.86842503
# [6436.14682267]
# -29519266.611033954
# [103346.34359222]
# -25866176.28986261
# [15598.66367729]
# -46897178.44021916
# [9.91695208]
# 18310.622361264264
# [145.55941563]
# 16071.8690957355
# [22.14122697]
# -6389.3470741664205
# [5.13650934]
# 682309.5368794044
# [143.44777974]
# 624531.1731168204
# [13.64483638]
# 654352.5435223564
# [731.17278896]
# 16316869.27932483
# [26138.66907523]
# 6665337.979617208
# [3325.0147501]
# 5055439.24211387
# [184.80434619]
# -63783.93291104678
# [3947.08595578]
# -646102.0026464397
# [585.96723148]
# -1394062.8361014286
# [300.36832067]
# -653236.9655188276
# [5554.35506405]
# -1036831.4840088221
# [787.49511087]
# -1849720.9576137736
# [1901.30712525]
# -8205243.844150504
# [33893.32215536]
# -9477836.413229784
# [5003.22757782]
# -15702408.434018264
# [233.92112703]
# -674171.9278206378
# [3810.27737726]
# ...
